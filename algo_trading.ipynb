# %%
# !pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download('AAPL', start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.454504
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.465665
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.362820
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.351056
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.393281
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.189484
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  133.810028
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.028381
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  130.902634
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  129.894333
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
a = [1, 2, 3, 5]
a
# Out:
# [1, 2, 3, 5]

# %%
ticker = ['SPY', 'AAPL', 'KO']

# %%
stocks = yf.download(ticker, start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.454504  18.209934   86.580750    7.643214  28.520000
# 2010-01-05    6.465665  17.989651   86.809952    7.656429  28.174999
# 2010-01-06    6.362820  17.983267   86.871056    7.534643  28.165001
# 2010-01-07    6.351056  17.938576   87.237762    7.520714  28.094999
# 2010-01-08    6.393281  17.606556   87.528053    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.189484  48.019436  350.743134  131.970001  53.439999
# 2020-12-28  133.810028  48.666401  353.756378  136.690002  54.160000
# 2020-12-29  132.028381  48.639446  353.081512  134.869995  54.130001
# 2020-12-30  130.902634  48.918003  353.585205  133.720001  54.439999
# 2020-12-31  129.894333  49.277428  355.381775  132.690002  54.840000
#
# ...

# %%
stocks.head()
# Out:
# Price      Adj Close                           Close                         \
# Ticker          AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.454504  18.209934  86.580750  7.643214  28.520000  113.330002
# 2010-01-05  6.465665  17.989651  86.809952  7.656429  28.174999  113.629997
# 2010-01-06  6.362820  17.983267  86.871056  7.534643  28.165001  113.709999
# 2010-01-07  6.351056  17.938576  87.237762  7.520714  28.094999  114.190002
# 2010-01-08  6.393281  17.606556  87.528053  7.570714  27.575001  114.570000
#
# Price           High                              Low                         \
# Ticker          AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks.tail()
# Out:
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2020-12-24  129.189484  48.019436  350.743134  131.970001  53.439999
# 2020-12-28  133.810028  48.666401  353.756378  136.690002  54.160000
# 2020-12-29  132.028381  48.639446  353.081512  134.869995  54.130001
# 2020-12-30  130.902634  48.918003  353.585205  133.720001  54.439999
# 2020-12-31  129.894333  49.277428  355.381775  132.690002  54.840000
#
# Price                         High                                Low  \
# Ticker             SPY        AAPL         KO         SPY        AAPL
# Date
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %%
stocks.to_csv('stocks.csv')

# %%
stocks = pd.read_csv('stocks.csv')

# %%
stocks
# Out:
#            Price           Adj Close         Adj Close.1         Adj Close.2  \
# 0         Ticker                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.454504489898682   18.20993423461914   86.58074951171875
# 3     2010-01-05   6.465664863586426   17.98965072631836   86.80995178222656
# 4     2010-01-06   6.362819671630859  17.983266830444336   86.87105560302734
# ...          ...                 ...                 ...                 ...
# 2766  2020-12-24  129.18948364257812   48.01943588256836   350.7431335449219
# 2767  2020-12-28  133.81002807617188   48.66640090942383   353.7563781738281
# 2768  2020-12-29  132.02838134765625   48.63944625854492   353.0815124511719
# 2769  2020-12-30   130.9026336669922   48.91800308227539    353.585205078125
# 2770  2020-12-31   129.8943328857422  49.277427673339844  355.38177490234375
#
# ...

# %%
stocks = pd.read_csv('stocks.csv', header=[0, 1])

# %%
stocks
# Out:
#            Price   Adj Close                              Close             \
#           Ticker        AAPL         KO         SPY        AAPL         KO
# 0           Date         NaN        NaN         NaN         NaN        NaN
# 1     2010-01-04    6.454504  18.209934   86.580750    7.643214  28.520000
# 2     2010-01-05    6.465665  17.989651   86.809952    7.656429  28.174999
# 3     2010-01-06    6.362820  17.983267   86.871056    7.534643  28.165001
# 4     2010-01-07    6.351056  17.938576   87.237762    7.520714  28.094999
# ...          ...         ...        ...         ...         ...        ...
# 2765  2020-12-24  129.189484  48.019436  350.743134  131.970001  53.439999
# 2766  2020-12-28  133.810028  48.666401  353.756378  136.690002  54.160000
# 2767  2020-12-29  132.028381  48.639446  353.081512  134.869995  54.130001
# 2768  2020-12-30  130.902634  48.918003  353.585205  133.720001  54.439999
# ...

# %%
stocks = pd.read_csv('stocks.csv', header=[0, 1], index_col=0)
stocks
# Out:
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.454504  18.209934   86.580750    7.643214  28.520000
# 2010-01-05    6.465665  17.989651   86.809952    7.656429  28.174999
# 2010-01-06    6.362820  17.983267   86.871056    7.534643  28.165001
# 2010-01-07    6.351056  17.938576   87.237762    7.520714  28.094999
# 2010-01-08    6.393281  17.606556   87.528053    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.189484  48.019436  350.743134  131.970001  53.439999
# 2020-12-28  133.810028  48.666401  353.756378  136.690002  54.160000
# 2020-12-29  132.028381  48.639446  353.081512  134.869995  54.130001
# 2020-12-30  130.902634  48.918003  353.585205  133.720001  54.439999
# 2020-12-31  129.894333  49.277428  355.381775  132.690002  54.840000
#
# ...

# %%
stocks = pd.read_csv('stocks.csv', header=[0, 1], index_col=[0], parse_dates=[0])
stocks
# Out:
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.454504  18.209934   86.580750    7.643214  28.520000
# 2010-01-05    6.465665  17.989651   86.809952    7.656429  28.174999
# 2010-01-06    6.362820  17.983267   86.871056    7.534643  28.165001
# 2010-01-07    6.351056  17.938576   87.237762    7.520714  28.094999
# 2010-01-08    6.393281  17.606556   87.528053    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.189484  48.019436  350.743134  131.970001  53.439999
# 2020-12-28  133.810028  48.666401  353.756378  136.690002  54.160000
# 2020-12-29  132.028381  48.639446  353.081512  134.869995  54.130001
# 2020-12-30  130.902634  48.918003  353.585205  133.720001  54.439999
# 2020-12-31  129.894333  49.277428  355.381775  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#convert mult index to one tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks.head()
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.454504        18.209934         86.580750
# 2010-01-05           6.465665        17.989651         86.809952
# 2010-01-06           6.362820        17.983267         86.871056
# 2010-01-07           6.351056        17.938576         87.237762
# 2010-01-08           6.393281        17.606556         87.528053
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# 2010-01-05       7.656429    28.174999    113.629997      7.699643
# 2010-01-06       7.534643    28.165001    113.709999      7.686786
# 2010-01-07       7.520714    28.094999    114.190002      7.571429
# 2010-01-08       7.570714    27.575001    114.570000      7.571429
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2010-01-04   28.610001   113.389999     7.585000  28.450001  111.510002
# ...

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.454504        18.209934         86.580750
# 2010-01-05           6.465665        17.989651         86.809952
# 2010-01-06           6.362820        17.983267         86.871056
# 2010-01-07           6.351056        17.938576         87.237762
# 2010-01-08           6.393281        17.606556         87.528053
# ...                       ...              ...               ...
# 2020-12-24         129.189484        48.019436        350.743134
# 2020-12-28         133.810028        48.666401        353.756378
# 2020-12-29         132.028381        48.639446        353.081512
# 2020-12-30         130.902634        48.918003        353.585205
# 2020-12-31         129.894333        49.277428        355.381775
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.454504  18.209934   86.580750    7.643214  28.520000
# 2010-01-05    6.465665  17.989651   86.809952    7.656429  28.174999
# 2010-01-06    6.362820  17.983267   86.871056    7.534643  28.165001
# 2010-01-07    6.351056  17.938576   87.237762    7.520714  28.094999
# 2010-01-08    6.393281  17.606556   87.528053    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.189484  48.019436  350.743134  131.970001  53.439999
# 2020-12-28  133.810028  48.666401  353.756378  136.690002  54.160000
# 2020-12-29  132.028381  48.639446  353.081512  134.869995  54.130001
# 2020-12-30  130.902634  48.918003  353.585205  133.720001  54.439999
# 2020-12-31  129.894333  49.277428  355.381775  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.443250    31.707147   180.904857    33.777537    41.320121
# std      24.521742     8.056273    69.264220    24.572747     6.808527
# min       5.792195    16.118813    78.772278     6.858929    25.014999
# 25%      15.143852    26.191202   114.157150    17.484285    37.660000
# 50%      24.456438    31.274166   174.871857    26.987499    41.759998
# 75%      40.776894    37.042503   240.407852    43.007500    45.549999
# max     133.810028    52.243057   355.381775   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
close = stocks.loc[:, 'Close'].copy()
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
plt.style.use('ggplot')
close.plot(figsize=(15, 8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0, 0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0, 0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0, 0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15, 8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl['lag1'] = aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl['difference'] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1  difference
# Date
# 2010-01-04    7.643214         NaN         NaN
# 2010-01-05    7.656429    7.643214    0.013215
# 2010-01-06    7.534643    7.656429   -0.121786
# 2010-01-07    7.520714    7.534643   -0.013929
# 2010-01-08    7.570714    7.520714    0.050000
# ...                ...         ...         ...
# 2020-12-24  131.970001  130.960007    1.009995
# 2020-12-28  136.690002  131.970001    4.720001
# 2020-12-29  134.869995  136.690002   -1.820007
# 2020-12-30  133.720001  134.869995   -1.149994
# 2020-12-31  132.690002  133.720001   -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl['% Change'] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1  difference  % Change
# Date
# 2010-01-04    7.643214         NaN         NaN       NaN
# 2010-01-05    7.656429    7.643214    0.013215  0.172893
# 2010-01-06    7.534643    7.656429   -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643   -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714    0.050000  0.664833
# ...                ...         ...         ...       ...
# 2020-12-24  131.970001  130.960007    1.009995  0.771224
# 2020-12-28  136.690002  131.970001    4.720001  3.576571
# 2020-12-29  134.869995  136.690002   -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995   -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001   -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
aapl['diff2'] = aapl.AAPL.diff(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1  difference  % Change     diff2
# Date
# 2010-01-04    7.643214         NaN         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214    0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429   -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643   -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714    0.050000  0.664833  0.050000
# ...                ...         ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007    1.009995  0.771224  1.009995
# 2020-12-28  136.690002  131.970001    4.720001  3.576571  4.720001
# 2020-12-29  134.869995  136.690002   -1.820007 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995   -1.149994 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001   -1.029999 -0.770265 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl['% Change 2'] = aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1  difference  % Change     diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN         NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214    0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429   -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643   -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714    0.050000  0.664833  0.050000    0.664833
# ...                ...         ...         ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007    1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001    4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002   -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995   -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001   -1.029999 -0.770265 -1.029999   -0.770265
#
# ...

# %%
del aapl['diff2']

# %%
del aapl['lag1']

# %%
aapl
# Out:
#                   AAPL  difference  % Change  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN         NaN
# 2010-01-05    7.656429    0.013215  0.172893    0.172893
# 2010-01-06    7.534643   -0.121786 -1.590632   -1.590632
# 2010-01-07    7.520714   -0.013929 -0.184871   -0.184871
# 2010-01-08    7.570714    0.050000  0.664833    0.664833
# ...                ...         ...       ...         ...
# 2020-12-24  131.970001    1.009995  0.771224    0.771224
# 2020-12-28  136.690002    4.720001  3.576571    3.576571
# 2020-12-29  134.869995   -1.820007 -1.331485   -1.331485
# 2020-12-30  133.720001   -1.149994 -0.852668   -0.852668
# 2020-12-31  132.690002   -1.029999 -0.770265   -0.770265
#
# [2769 rows x 4 columns]

# %%
aapl.rename(columns = {'% Change': 'Daily Change'}, inplace=True)

# %%
aapl
# Out:
#                   AAPL  difference  Daily Change  % Change 2
# Date
# 2010-01-04    7.643214         NaN           NaN         NaN
# 2010-01-05    7.656429    0.013215      0.172893    0.172893
# 2010-01-06    7.534643   -0.121786     -1.590632   -1.590632
# 2010-01-07    7.520714   -0.013929     -0.184871   -0.184871
# 2010-01-08    7.570714    0.050000      0.664833    0.664833
# ...                ...         ...           ...         ...
# 2020-12-24  131.970001    1.009995      0.771224    0.771224
# 2020-12-28  136.690002    4.720001      3.576571    3.576571
# 2020-12-29  134.869995   -1.820007     -1.331485   -1.331485
# 2020-12-30  133.720001   -1.149994     -0.852668   -0.852668
# 2020-12-31  132.690002   -1.029999     -0.770265   -0.770265
#
# [2769 rows x 4 columns]

# %%
del aapl['difference']

# %%
aapl
# Out:
#                   AAPL  Daily Change  % Change 2
# Date
# 2010-01-04    7.643214           NaN         NaN
# 2010-01-05    7.656429      0.172893    0.172893
# 2010-01-06    7.534643     -1.590632   -1.590632
# 2010-01-07    7.520714     -0.184871   -0.184871
# 2010-01-08    7.570714      0.664833    0.664833
# ...                ...           ...         ...
# 2020-12-24  131.970001      0.771224    0.771224
# 2020-12-28  136.690002      3.576571    3.576571
# 2020-12-29  134.869995     -1.331485   -1.331485
# 2020-12-30  133.720001     -0.852668   -0.852668
# 2020-12-31  132.690002     -0.770265   -0.770265
#
# [2769 rows x 3 columns]

# %%
aapl.AAPL.resample('M').last()
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/653021685.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample('M').last()
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: ME, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample('BM').last().pct_change(periods=1).mul(100) # last business day of the month
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/2300284063.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample('BM').last().pct_change(periods=1).mul(100) # last business day of the month
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BME, Name: AAPL, Length: 132, dtype: float64

# %%
del aapl['Daily Change']

# %%
aapl
# Out:
#                   AAPL  % Change 2
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    0.172893
# 2010-01-06    7.534643   -1.590632
# 2010-01-07    7.520714   -0.184871
# 2010-01-08    7.570714    0.664833
# ...                ...         ...
# 2020-12-24  131.970001    0.771224
# 2020-12-28  136.690002    3.576571
# 2020-12-29  134.869995   -1.331485
# 2020-12-30  133.720001   -0.852668
# 2020-12-31  132.690002   -0.770265
#
# [2769 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
aapl
# Out:
#                   AAPL  % Change 2
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    0.172893
# 2010-01-06    7.534643   -1.590632
# 2010-01-07    7.520714   -0.184871
# 2010-01-08    7.570714    0.664833
# ...                ...         ...
# 2020-12-24  131.970001    0.771224
# 2020-12-28  136.690002    3.576571
# 2020-12-29  134.869995   -1.331485
# 2020-12-30  133.720001   -0.852668
# 2020-12-31  132.690002   -0.770265
#
# [2769 rows x 2 columns]

# %%
ret
# Out:
#                 AAPL  % Change 2
# Date
# 2010-01-06 -0.015906  -10.200093
# 2010-01-07 -0.001849   -0.883775
# 2010-01-08  0.006648   -4.596201
# 2010-01-11 -0.008821   -2.326871
# 2010-01-12 -0.011375    0.289481
# ...              ...         ...
# 2020-12-24  0.007712   -2.105535
# 2020-12-28  0.035766    3.637528
# 2020-12-29 -0.013315   -1.372280
# 2020-12-30 -0.008527   -0.359611
# 2020-12-31 -0.007703   -0.096641
#
# [2767 rows x 2 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2767 entries, 2010-01-06 to 2020-12-31
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AAPL        2767 non-null   float64
#  1   % Change 2  2767 non-null   float64
# dtypes: float64(2)
# memory usage: 64.9 KB

# %%
# ret.plot(kind='hist', figsize=(12, 8), bins=100)
# plt.show()

# %%
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# /Users/mwilko777/.pyenv/versions/3.11.0/lib/python3.11/site-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# AAPL          0.001191
# % Change 2         NaN
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL          0.000318
# % Change 2         NaN
# dtype: float64

# %%
std_daily = ret.std()
std_daily
# Out:
# AAPL          0.017846
# % Change 2         NaN
# dtype: float64

# %%
annual_mean_ret = daily_mean_ret * 252
annual_mean_ret
# Out:
# AAPL          0.300085
# % Change 2         NaN
# dtype: float64

# %%
annual_var_ret = var_daily * 252
annual_var_ret
# Out:
# AAPL          0.080255
# % Change 2         NaN
# dtype: float64

# %%
annual_std_ret = std_daily * np.sqrt(252)
annual_std_ret
# Out:
# AAPL          0.283293
# % Change 2         NaN
# dtype: float64

# %%
ticker = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA', 'IBM']

# %%
stocks = yf.download(ticker, start='2010-01-01', end='2024-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close = stocks.loc[:, 'Close'].copy()

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15, 8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL      AMZN     GOOGL       IBM      MSFT      NVDA
# Date
# 2010-01-05  0.001729  0.005900 -0.004404 -0.012080  0.000323  0.014603
# 2010-01-06 -0.015906 -0.018116 -0.025209 -0.006496 -0.006137  0.006397
# 2010-01-07 -0.001849 -0.017013 -0.023280 -0.003462 -0.010400 -0.019597
# 2010-01-08  0.006648  0.027077  0.013331  0.010035  0.006897  0.002161
# 2010-01-11 -0.008821 -0.024041 -0.001512 -0.010470 -0.012720 -0.014016

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    3521.0  0.001075  0.017774 -0.128647 -0.007553  0.000897  0.010421
# AMZN    3521.0  0.001103  0.020808 -0.140494 -0.009080  0.000955  0.011905
# GOOGL   3521.0  0.000768  0.017186 -0.116341 -0.007220  0.000723  0.009209
# IBM     3521.0  0.000171  0.014004 -0.128507 -0.006262  0.000389  0.006994
# MSFT    3521.0  0.000843  0.016351 -0.147390 -0.007243  0.000638  0.009205
# NVDA    3521.0  0.001724  0.028276 -0.187559 -0.012205  0.001570  0.015337
#
#              max
# Ticker
# AAPL    0.119808
# AMZN    0.157457
# GOOGL   0.162584
# IBM     0.113010
# MSFT    0.142169
# NVDA    0.298067

# %%
summary = ret.describe().T.loc[:, ['mean', 'std']]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001075  0.017774
# AMZN    0.001103  0.020808
# GOOGL   0.000768  0.017186
# IBM     0.000171  0.014004
# MSFT    0.000843  0.016351
# NVDA    0.001724  0.028276

# %%
summary['mean'] = summary['mean'] * 252
summary['std'] = summary['std'] * np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.270849  0.282148
# AMZN    0.277924  0.330323
# GOOGL   0.193632  0.272822
# IBM     0.043154  0.222300
# MSFT    0.212473  0.259568
# NVDA    0.434495  0.448872

# %%
summary.plot(kind='scatter', x='std', y='mean', figsize=(12, 8), s=50, fontsize=15)

for i in summary.index:
    plt.text(summary.loc[i, 'std'] + 0.002, summary.loc[i, 'mean'], i, fontsize=15)

plt.xlabel('ann. Risk(std)', fontsize=15)
plt.ylabel('ann. Return', fontsize=15)
plt.title('Risk/Return', fontsize=20)
plt.show()

# %%
fruits = ['apple', 'banana', 'cherry']
for i in fruits:
    print(i)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ### Correlation and Covariance

# %%
ret
# Out:
# Ticker          AAPL      AMZN     GOOGL       IBM      MSFT      NVDA
# Date
# 2010-01-05  0.001729  0.005900 -0.004404 -0.012080  0.000323  0.014603
# 2010-01-06 -0.015906 -0.018116 -0.025209 -0.006496 -0.006137  0.006397
# 2010-01-07 -0.001849 -0.017013 -0.023280 -0.003462 -0.010400 -0.019597
# 2010-01-08  0.006648  0.027077  0.013331  0.010035  0.006897  0.002161
# 2010-01-11 -0.008821 -0.024041 -0.001512 -0.010470 -0.012720 -0.014016
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22 -0.005547 -0.002730  0.007620  0.008459  0.002784 -0.003266
# 2023-12-26 -0.002841 -0.000065  0.000212  0.006599  0.000214  0.009195
# 2023-12-27  0.000518 -0.000456 -0.008126  0.001532 -0.001575  0.002800
# 2023-12-28  0.002226  0.000261 -0.000997  0.001774  0.003235  0.002125
# 2023-12-29 -0.005424 -0.009388 -0.003851 -0.001221  0.002025  0.000000
#
# [3521 rows x 6 columns]

# %%
ret.cov()
# Out:
# Ticker      AAPL      AMZN     GOOGL       IBM      MSFT      NVDA
# Ticker
# AAPL    0.000316  0.000179  0.000171  0.000101  0.000172  0.000252
# AMZN    0.000179  0.000433  0.000214  0.000092  0.000192  0.000272
# GOOGL   0.000171  0.000214  0.000295  0.000097  0.000180  0.000249
# IBM     0.000101  0.000092  0.000097  0.000196  0.000106  0.000136
# MSFT    0.000172  0.000192  0.000180  0.000106  0.000267  0.000264
# NVDA    0.000252  0.000272  0.000249  0.000136  0.000264  0.000800

# %%
ret.corr()
# Out:
# Ticker      AAPL      AMZN     GOOGL       IBM      MSFT      NVDA
# Ticker
# AAPL    1.000000  0.485247  0.558210  0.406600  0.591559  0.501501
# AMZN    0.485247  1.000000  0.599523  0.315339  0.564944  0.463082
# GOOGL   0.558210  0.599523  1.000000  0.404749  0.639805  0.511388
# IBM     0.406600  0.315339  0.404749  1.000000  0.464860  0.344159
# MSFT    0.591559  0.564944  0.639805  0.464860  1.000000  0.570512
# NVDA    0.501501  0.463082  0.511388  0.344159  0.570512  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12, 8))
sns.set_theme(font_scale=1.4)
sns.heatmap(ret.corr(), annot=True, cmap='Reds', annot_kws={'size': 15}, vmax=0.6)
plt.show()

# %% [markdown]
# ### Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016, 2017, 2018], data=[100, 50, 95], columns=['Price'])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simple_ret = df.pct_change().dropna()
simple_ret
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simple_ret.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
#mean ret are miss leading

# %%
log_ret = np.log(df/df.shift(1)).dropna()
log_ret
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_ret.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(log_ret.mean()*2)
#ending price of 2018 / log returns is more accurate
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download('SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy = SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-08-27  561.559998
# 2024-08-28  558.299988
# 2024-08-29  558.349976
# 2024-08-30  563.679993
# 2024-09-03  555.820007
#
# [7955 rows x 1 columns]

# %%
spy.plot(figsize=(12, 8), fontsize=15)
plt.legend(loc = "upper left", fontsize=15)
plt.show()

# %%
spy_roll = spy.rolling(window=10)

# %%
spy_roll = spy_roll.mean()

# %%
spy_roll
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-08-27  557.075995
# 2024-08-28  558.530994
# 2024-08-29  559.058990
# 2024-08-30  559.995990
# 2024-09-03  559.616992
#
# [7955 rows x 1 columns]

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-08-27  559.154999
# 2024-08-28  559.154999
# 2024-08-29  559.154999
# 2024-08-30  560.114990
# 2024-09-03  559.660004
#
# [7955 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-08-27  562.130005
# 2024-08-28  562.130005
# 2024-08-29  562.130005
# 2024-08-30  563.679993
# 2024-09-03  563.679993
#
# [7955 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-08-27  561.559998
# 2024-08-28  558.299988
# 2024-08-29  558.349976
# 2024-08-30  563.679993
# 2024-09-03  555.820007
#
# [7955 rows x 1 columns]

# %%
spy["SMA50"] = spy.rolling(window=50).mean()

# %%
spy
# Out:
#                  Close       SMA50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2024-08-27  561.559998  547.979601
# 2024-08-28  558.299988  548.203601
# 2024-08-29  558.349976  548.400801
# 2024-08-30  563.679993  548.734401
# 2024-09-03  555.820007  548.960601
#
# [7955 rows x 2 columns]

# %%
spy.plot(figsize=(12, 8), fontsize=15)
plt.legend(loc = "upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"] = spy.Close.rolling(window=200, min_periods=200).mean()
spy.plot(figsize=(12, 8), fontsize=15)
plt.legend(loc = "upper left", fontsize=15)
plt.show()

# %%
spy["EMA100"] = spy.Close.ewm(span=100, min_periods=100).mean()

# %%
spy
# Out:
#                  Close       SMA50     SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN
# 1993-02-01   44.250000         NaN        NaN         NaN
# 1993-02-02   44.343750         NaN        NaN         NaN
# 1993-02-03   44.812500         NaN        NaN         NaN
# 1993-02-04   45.000000         NaN        NaN         NaN
# ...                ...         ...        ...         ...
# 2024-08-27  561.559998  547.979601  509.66125  534.213971
# 2024-08-28  558.299988  548.203601  510.28355  534.690922
# 2024-08-29  558.349976  548.400801  510.87225  535.159418
# 2024-08-30  563.679993  548.734401  511.48970  535.724182
# 2024-09-03  555.820007  548.960601  512.02515  536.122119
#
# [7955 rows x 4 columns]

# %%
spy.plot(figsize=(12, 8), fontsize=15)
plt.legend(loc = "upper left", fontsize=15)
plt.show()

# %%
spy["Day"] = spy.index.day_name()

# %%
spy
# Out:
#                  Close       SMA50     SMA200      EMA100        Day
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN        NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN        NaN         NaN   Thursday
# ...                ...         ...        ...         ...        ...
# 2024-08-27  561.559998  547.979601  509.66125  534.213971    Tuesday
# 2024-08-28  558.299988  548.203601  510.28355  534.690922  Wednesday
# 2024-08-29  558.349976  548.400801  510.87225  535.159418   Thursday
# 2024-08-30  563.679993  548.734401  511.48970  535.724182     Friday
# 2024-09-03  555.820007  548.960601  512.02515  536.122119    Tuesday
#
# [7955 rows x 5 columns]

# %%
spy["Quarter"] = spy.index.quarter

# %%
spy
# Out:
#                  Close       SMA50     SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN        NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN        NaN         NaN   Thursday        1
# ...                ...         ...        ...         ...        ...      ...
# 2024-08-27  561.559998  547.979601  509.66125  534.213971    Tuesday        3
# 2024-08-28  558.299988  548.203601  510.28355  534.690922  Wednesday        3
# 2024-08-29  558.349976  548.400801  510.87225  535.159418   Thursday        3
# 2024-08-30  563.679993  548.734401  511.48970  535.724182     Friday        3
# 2024-09-03  555.820007  548.960601  512.02515  536.122119    Tuesday        3
#
# [7955 rows x 6 columns]

# %%
SPY = yf.download('SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
all_days = pd.date_range(start='2010-01-01', end='2020-01-01', freq='D')
all_days
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3653, freq='D')

# %%
spy
# Out:
#                  Close       SMA50     SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN        NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN        NaN         NaN   Thursday        1
# ...                ...         ...        ...         ...        ...      ...
# 2024-08-27  561.559998  547.979601  509.66125  534.213971    Tuesday        3
# 2024-08-28  558.299988  548.203601  510.28355  534.690922  Wednesday        3
# 2024-08-29  558.349976  548.400801  510.87225  535.159418   Thursday        3
# 2024-08-30  563.679993  548.734401  511.48970  535.724182     Friday        3
# 2024-09-03  555.820007  548.960601  512.02515  536.122119    Tuesday        3
#
# [7955 rows x 6 columns]

# %%
spy = spy.reindex(all_days)

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100      Day  Quarter
# 2010-01-01         NaN         NaN         NaN         NaN      NaN      NaN
# 2010-01-02         NaN         NaN         NaN         NaN      NaN      NaN
# 2010-01-03         NaN         NaN         NaN         NaN      NaN      NaN
# 2010-01-04  113.330002  109.766200   98.780800  106.656766   Monday      1.0
# 2010-01-05  113.629997  109.852200   98.965400  106.794850  Tuesday      1.0
# ...                ...         ...         ...         ...      ...      ...
# 2019-12-28         NaN         NaN         NaN         NaN      NaN      NaN
# 2019-12-29         NaN         NaN         NaN         NaN      NaN      NaN
# 2019-12-30  321.079987  311.279599  296.249949  305.606695   Monday      4.0
# 2019-12-31  321.859985  311.757399  296.447599  305.928543  Tuesday      4.0
# 2020-01-01         NaN         NaN         NaN         NaN      NaN      NaN
#
# [3653 rows x 6 columns]

# %%
spy.fillna(method='ffill')
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/3145680167.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method='ffill')
#                  Close       SMA50      SMA200      EMA100      Day  Quarter
# 2010-01-01         NaN         NaN         NaN         NaN      NaN      NaN
# 2010-01-02         NaN         NaN         NaN         NaN      NaN      NaN
# 2010-01-03         NaN         NaN         NaN         NaN      NaN      NaN
# 2010-01-04  113.330002  109.766200   98.780800  106.656766   Monday      1.0
# 2010-01-05  113.629997  109.852200   98.965400  106.794850  Tuesday      1.0
# ...                ...         ...         ...         ...      ...      ...
# 2019-12-28  322.859985  310.843599  296.051099  305.294103   Friday      4.0
# 2019-12-29  322.859985  310.843599  296.051099  305.294103   Friday      4.0
# ...

# %%
spy.fillna(method='bfill')
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/2982224753.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method='bfill')
#                  Close       SMA50      SMA200      EMA100      Day  Quarter
# 2010-01-01  113.330002  109.766200   98.780800  106.656766   Monday      1.0
# 2010-01-02  113.330002  109.766200   98.780800  106.656766   Monday      1.0
# 2010-01-03  113.330002  109.766200   98.780800  106.656766   Monday      1.0
# 2010-01-04  113.330002  109.766200   98.780800  106.656766   Monday      1.0
# 2010-01-05  113.629997  109.852200   98.965400  106.794850  Tuesday      1.0
# ...                ...         ...         ...         ...      ...      ...
# 2019-12-28  321.079987  311.279599  296.249949  305.606695   Monday      4.0
# 2019-12-29  321.079987  311.279599  296.249949  305.606695   Monday      4.0
# ...

# %%
SPY = yf.download('SPY', interval='1wk')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.684095
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.263458
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.052780
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.473429
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   24.947460
# ...                ...         ...         ...         ...         ...
# 2024-08-05  511.640015  534.510010  510.269989  532.989990  532.989990
# 2024-08-12  534.210022  555.020020  530.950012  554.309998  554.309998
# 2024-08-19  554.729980  563.179993  553.859985  562.130005  562.130005
# 2024-08-26  563.179993  564.200012  555.039978  563.679993  563.679993
# 2024-09-02  558.349976  560.804993  555.780029  555.830017  555.830017
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# ...

# %% [markdown]
# ### Cummaltive Returns, Drawdowns etc...

# %%
apple = yf.download('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2024-08-27  228.029999
# 2024-08-28  226.490005
# 2024-08-29  229.789993
# 2024-08-30  229.000000
# 2024-09-03  224.160004
#
# [11022 rows x 1 columns]

# %%
apple['d_returns'] = np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2024-08-27  228.029999   0.003735
# 2024-08-28  226.490005  -0.006776
# 2024-08-29  229.789993   0.014465
# 2024-08-30  229.000000  -0.003444
# 2024-09-03  224.160004  -0.021362
#
# [11022 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2024-08-27  228.029999   0.003735
# 2024-08-28  226.490005  -0.006776
# 2024-08-29  229.789993   0.014465
# 2024-08-30  229.000000  -0.003444
# 2024-09-03  224.160004  -0.021362
#
# [11021 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.465370108445495

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1746.5018236938222

# %%
apple['cummreturns'] = apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2024-08-27  228.029999   0.003735  1776.654185
# 2024-08-28  226.490005  -0.006776  1764.655608
# 2024-08-29  229.789993   0.014465  1790.366862
# 2024-08-30  229.000000  -0.003444  1784.211773
# 2024-09-03  224.160004  -0.021362  1746.501824
#
# [11021 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12, 8), fontsize=15, title = 'Apple Buy and Hold Strategy')
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.1706989626466078

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.44909380399162596

# %%
# how to calculate drawdowns
apple['cummmax'] = apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300
#
# [11021 rows x 4 columns]

# %%
apple[['cummreturns', 'cummmax']].plot(figsize=(12, 8), fontsize=15, title = 'Apple Buy and Hold Strategy + Cummmax')
plt.show()

# %%
apple['drawdown'] = apple['cummmax'] - apple['cummreturns']

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300  52.903114
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300  64.901691
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300  39.190438
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300  45.345527
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300  83.055476
#
# [11021 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402015

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index <= '2023-01-05')]
# Out:
#                  Close  d_returns  cummreturns      cummmax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple['drawdown%'] = (apple['cummmax'] - apple['cummreturns'])/apple['cummmax']

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300  52.903114
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300  64.901691
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300  39.190438
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300  45.345527
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300  83.055476
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# ...

# %%
apple['drawdown%'].max()
# Out:
# 0.82216567924191

# %%
apple['drawdown%'].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index <= '1997-12-23')]
# Out:
#                Close  d_returns  cummreturns   cummmax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300  52.903114
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300  64.901691
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300  39.190438
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300  45.345527
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300  83.055476
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# ...

# %% [markdown]
# ## SMA Strategy

# %%
data  = apple.loc[(apple.index >= '1991-01-01')]

# %%
data
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1991-01-02    0.388393   0.011560     3.026093     4.121747   1.095654
# 1991-01-03    0.383929  -0.011560     2.991313     4.121747   1.130434
# 1991-01-04    0.386161   0.005797     3.008703     4.121747   1.113044
# 1991-01-07    0.386161   0.000000     3.008703     4.121747   1.113044
# 1991-01-08    0.386161   0.000000     3.008703     4.121747   1.113044
# ...                ...        ...          ...          ...        ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300  52.903114
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300  64.901691
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300  39.190438
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300  45.345527
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300  83.055476
#
#             drawdown%
# Date
# 1991-01-02   0.265823
# 1991-01-03   0.274261
# 1991-01-04   0.270042
# ...

# %%
sma_s = 50
sms_l= 100

# %%
data['sma_s'] = data['Close'].rolling(window=sma_s).mean()
data['sma_l'] = data['Close'].rolling(window=sms_l).mean()
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/56832170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sma_s'] = data['Close'].rolling(window=sma_s).mean()
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/56832170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sma_l'] = data['Close'].rolling(window=sms_l).mean()

# %%
data
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1991-01-02    0.388393   0.011560     3.026093     4.121747   1.095654
# 1991-01-03    0.383929  -0.011560     2.991313     4.121747   1.130434
# 1991-01-04    0.386161   0.005797     3.008703     4.121747   1.113044
# 1991-01-07    0.386161   0.000000     3.008703     4.121747   1.113044
# 1991-01-08    0.386161   0.000000     3.008703     4.121747   1.113044
# ...                ...        ...          ...          ...        ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300  52.903114
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300  64.901691
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300  39.190438
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300  45.345527
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300  83.055476
#
#             drawdown%     sma_s     sma_l
# Date
# 1991-01-02   0.265823       NaN       NaN
# ...

# %%
data.plot(figsize=(12, 8), fontsize=15, title='Apple - SMA{} | SMA{}'.format(sma_s, sms_l))
plt.show()

# %%
data.loc['2016'].plot(figsize=(12, 8), fontsize=15, title='Apple - SMA{} | SMA{}'.format(sma_s, sms_l))
plt.show()

# %%
data.dropna(inplace=True)
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/1368182302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
data
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1991-05-23    0.402902  -0.024623     3.139138     5.060882   1.921744
# 1991-05-24    0.409598   0.016483     3.191308     5.060882   1.869574
# 1991-05-28    0.410714   0.002721     3.200003     5.060882   1.860878
# 1991-05-29    0.419643   0.021507     3.269572     5.060882   1.791310
# 1991-05-30    0.425223   0.013209     3.313047     5.060882   1.747834
# ...                ...        ...          ...          ...        ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300  52.903114
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300  64.901691
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300  39.190438
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300  45.345527
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300  83.055476
#
#             drawdown%       sma_s       sma_l
# Date
# 1991-05-23   0.379725    0.534420    0.513326
# ...

# %%
data['position'] = np.where(data['sma_s'] > data['sma_l'], 1, -1)
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/3500922721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'] = np.where(data['sma_s'] > data['sma_l'], 1, -1)

# %%
data
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1991-05-23    0.402902  -0.024623     3.139138     5.060882   1.921744
# 1991-05-24    0.409598   0.016483     3.191308     5.060882   1.869574
# 1991-05-28    0.410714   0.002721     3.200003     5.060882   1.860878
# 1991-05-29    0.419643   0.021507     3.269572     5.060882   1.791310
# 1991-05-30    0.425223   0.013209     3.313047     5.060882   1.747834
# ...                ...        ...          ...          ...        ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300  52.903114
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300  64.901691
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300  39.190438
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300  45.345527
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300  83.055476
#
#             drawdown%       sma_s       sma_l  position
# Date
# ...

# %%
data.loc[:, ['sma_s', 'sma_l', 'position']].plot(figsize=(12, 8), fontsize=15, title='Apple - SMA{} | SMA{}'.format(sma_s, sms_l), secondary_y='position')
plt.show()

# %%
data.loc['2016', ['sma_s', 'sma_l', 'position']].plot(figsize=(12, 8), fontsize=15, title='Apple - SMA{} | SMA{}'.format(sma_s, sms_l), secondary_y='position')
plt.show()

# %%
data['returnsb&h'] = np.log(data['Close']/data['Close'].shift(1))
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/976030013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['returnsb&h'] = np.log(data['Close']/data['Close'].shift(1))

# %%
data['strategy'] = data['position'].shift(1) * data['returnsb&h']
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/1955919874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['strategy'] = data['position'].shift(1) * data['returnsb&h']

# %%
data
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1991-05-23    0.402902  -0.024623     3.139138     5.060882   1.921744
# 1991-05-24    0.409598   0.016483     3.191308     5.060882   1.869574
# 1991-05-28    0.410714   0.002721     3.200003     5.060882   1.860878
# 1991-05-29    0.419643   0.021507     3.269572     5.060882   1.791310
# 1991-05-30    0.425223   0.013209     3.313047     5.060882   1.747834
# ...                ...        ...          ...          ...        ...
# 2024-08-27  228.029999   0.003735  1776.654185  1829.557300  52.903114
# 2024-08-28  226.490005  -0.006776  1764.655608  1829.557300  64.901691
# 2024-08-29  229.789993   0.014465  1790.366862  1829.557300  39.190438
# 2024-08-30  229.000000  -0.003444  1784.211773  1829.557300  45.345527
# 2024-09-03  224.160004  -0.021362  1746.501824  1829.557300  83.055476
#
#             drawdown%       sma_s       sma_l  position  returnsb&h  strategy
# Date
# ...

# %%
data.dropna(inplace=True)
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/1368182302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
data[['returnsb&h', 'strategy']].sum()
# Out:
# returnsb&h    6.321422
# strategy      1.669041
# dtype: float64

# %%
data[['returnsb&h', 'strategy']].sum().apply(np.exp) # what $1 would be at the end of the period
# Out:
# returnsb&h    556.363581
# strategy        5.307076
# dtype: float64

# %%
data[['returnsb&h', 'strategy']].std() * np.sqrt(252) # analyze std
# Out:
# returnsb&h    0.431892
# strategy      0.432047
# dtype: float64

# %%
data.Close.plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data['position2'] = np.where(data['sma_s'] > data['sma_l'], 1, 0)
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/2459756394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position2'] = np.where(data['sma_s'] > data['sma_l'], 1, 0)

# %%
data['strategy2'] = data['position2'].shift(1) * data['returnsb&h']
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/3408756221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['strategy2'] = data['position2'].shift(1) * data['returnsb&h']

# %%
data.dropna(inplace=True)
# Out:
# /var/folders/31/9bd8ksys1rzbjk8qs9scl95h0000gn/T/ipykernel_51016/1368182302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
data[['returnsb&h', 'strategy2']].sum()
# Out:
# returnsb&h    6.304939
# strategy2     3.978749
# dtype: float64

# %%
data[['returnsb&h', 'strategy2']].sum().apply(np.exp)
# Out:
# returnsb&h    547.268316
# strategy2      53.450112
# dtype: float64

# %%
data[['returnsb&h', 'strategy2']].std() * np.sqrt(252)
# Out:
# returnsb&h    0.431910
# strategy2     0.333691
# dtype: float64

# %%
## Strategy 2 is better than strategy 1
data[['strategy', 'strategy2']].std() * np.sqrt(252)
# Out:
# strategy     0.432063
# strategy2    0.333691
# dtype: float64

# %% [markdown]
# ## Creating our first function

# %%
def test_strategy(stock, start_date, end_date, SMA):
    df = yf.download(stock, start=start_date, end=end_date)
    data = df.Close.to_frame()
    data['returns'] = np.log(data.Close.div(data.Close.shift(1)))
    data['SMA_S'] = data['Close'].rolling(int(SMA[0])).mean()
    data['SMA_L'] = data['Close'].rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data['position'] = np.where(data['sma_s'] > data['sma_l'], 1, -1)
    data['strategy'] = data['position'].shift(1) * data['returns']
    data.dropna(inplace=True)
    ret = np.exp(data[['strategy']].sum()) 
    std = data[['strategy']].std() * np.sqrt(252)

    return ret, std

# %%
test_strategy('SPY', '2000-01-01', '2020-01-01', [50, 200])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (strategy    4.766372
#  dtype: float64,
#  strategy    0.187879
#  dtype: float64)

# %% [markdown]
# ### Creating our first Class

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        raw = yf.download(self.symbol, start=self.start, end=self.end)
        data = raw.Close.to_frame()
        data['returns'] = np.log(data['Close'] / data['Close'].shift(1))
        data['SMA_S'] = data['Close'].rolling(self.SMA_S).mean()
        data['SMA_L'] = data['Close'].rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data = data

    def test_strategy(self):
        data = self.data.copy().dropna()
        data['position'] = np.where(data['SMA_S'] > data['SMA_L'], 1, -1)
        data['strategy'] = data['position'].shift(1) * data['returns']
        data.dropna(inplace=True)

        data['returnsbh'] = data['returns'].cumsum().apply(np.exp)
        data['returnstrategy'] = data['strategy'].cumsum().apply(np.exp)
        perf = data['returnstrategy'].iloc[-1]
        outperf = perf - data['returnstrategy'].iloc[-1]
        self.results = data

        ret = np.exp(data[['returns', 'strategy']].sum())
        std = data[['returns', 'strategy']].std() * np.sqrt(252)

        return round(perf, 6), round(outperf, 6)
    
    def plot_results(self):
        if self.results is None:
            print('No results to plot')
        else:
            title = f'{self.symbol} | SMA_S = {self.SMA_S} | SMA_L = {self.SMA_L}'
            self.results[['returnsbh', 'returnstrategy']].plot(title = title, figsize=(12, 8))
            plt.show()

# %%
tester = SMABacktester('AAPL', 50, 200, '2000-01-01', '2020-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_strategy()
# Out:
# (16.540321, 0.0)

# %%
tester.plot_results()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[205], line 1
# ----> 1 tester.plot_results()
#
# Cell In[202], line 42, in SMABacktester.plot_results(self)
#      40 else:
#      41     title : f'{self.symbol} | SMA_S = {self.SMA_S} | SMA_L = {self.SMA_L}'
# ---> 42     self.results[['returnsbh', 'returnstrategy']].plot(title = title, figsize=(12, 8))
#      43     plt.show()
#
# UnboundLocalError: cannot access local variable 'title' where it is not associated with a value
